# %% [markdown]
# ## Combined Cycle Power Plant
#
# A combined cycle power plant (CCPP) is composed of gas turbines (GT), steam turbines (ST) and heat recovery steam generators. In a CCPP, the electricity is generated by gas and steam turbines, which are combined in one cycle, and is transferred from one turbine to another.The dataset contains 9568 data points collected from a Combined Cycle Power Plant over 6 years (2006-2011), when the power plant was set to work with full load.
#
# We need to predict the net hourly electrical energy output(PE) of the power plant using the features of Temperature(AT), Ambient Pressure(AP), Relative Humidity(RH) and Exhaust Vacuum(V).
#
# Combined Cycle Power Plant [dataset](https://archive.ics.uci.edu/ml/datasets/combined+cycle+power+plant)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Data Preprocessing

# %%
df=pd.read_excel("Combine_Cycle_Power_Plant.xlsx")

# %%
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# 5     26.27  59.44  1012.23  58.77  443.67
# 6     15.89  43.96  1014.02  75.24  467.35
# 7      9.48  44.71  1019.12  66.43  478.42
# 8     14.64  45.00  1021.78  41.25  475.98
# 9     11.74  43.56  1015.14  70.72  477.50
# 10    17.99  43.72  1008.64  75.04  453.02
# 11    20.14  46.93  1014.66  64.22  453.99
# 12    24.34  73.50  1011.31  84.15  440.29
# 13    25.71  58.59  1012.77  61.83  451.28
# 14    26.19  69.34  1009.48  87.59  433.99
# 15    21.42  43.79  1015.76  43.08  462.19
# 16    18.21  45.00  1022.86  48.84  467.54
# 17    11.04  41.74  1022.60  77.51  477.20
# 18    14.45  52.75  1023.97  63.59  459.85
# 19    13.97  38.47  1015.15  55.28  464.30
# 20    17.76  42.42  1009.09  66.26  468.27
# 21     5.41  40.07  1019.16  64.77  495.24
# 22     7.76  42.28  1008.52  83.31  483.80
# 23    27.23  63.90  1014.30  47.19  443.61
# 24    27.36  48.60  1003.18  54.93  436.06
# 25    27.47  70.72  1009.97  74.62  443.25
# 26    14.60  39.31  1011.11  72.52  464.16
# 27     7.91  39.96  1023.57  88.44  475.52
# 28     5.81  35.79  1012.14  92.28  484.41
# 29    30.53  65.18  1012.69  41.85  437.89
# ...     ...    ...      ...    ...     ...
# 9538   8.64  38.56  1016.51  66.03  484.45
# 9539  10.53  37.50  1008.55  99.91  472.32
# 9540  23.53  50.05  1005.63  78.40  443.71
# 9541  24.90  67.25  1017.77  66.17  433.71
# 9542   5.01  39.40  1003.69  91.90  475.34
# 9543  22.66  69.84  1006.16  82.79  439.06
# 9544  29.76  57.19  1008.59  51.10  436.21
# 9545  26.30  61.41  1012.45  56.85  448.55
# 9546  30.17  74.22  1007.46  49.27  432.00
# 9547   8.02  40.23  1017.42  90.26  484.22
# 9548  19.12  50.16  1011.52  99.71  451.49
# 9549  14.87  42.18  1015.23  74.41  465.89
# 9550   9.71  42.44  1014.29  94.03  481.03
# 9551  24.33  77.54  1008.50  82.45  435.38
# 9552   7.17  39.40  1011.48  90.38  484.33
# 9553  24.61  62.96  1020.10  63.83  445.79
# 9554  23.48  66.44  1011.28  61.11  443.21
# 9555  23.70  70.32  1007.21  66.85  439.59
# 9556  25.44  69.59  1008.22  80.73  433.97
# 9557  17.46  62.10  1019.96  83.99  451.06
# 9558  22.97  62.40  1010.25  75.18  445.30
# 9559  26.22  49.82  1015.48  55.80  454.20
# 9560  23.27  68.28  1005.01  74.83  444.86
# 9561  11.76  41.58  1020.91  88.35  465.45
# 9562  14.02  40.10  1015.56  82.44  467.32
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# ### Data Visualization and Feature Selection
#
# When we plot the graph for all features(Temperature [AT], Pressure [AP], Humidity [RH], Vaccum [V])  with respect to the target(Electric Energy [PE]) the datapoints are linearly distributed that is all data points are either increasing or decreasing with respect to the target.
#
# Since all the features are linearly distributed so all the features are required to implement the model.

# %%
feature=pd.concat([df.AT,df.V,df.AP,df.RH],axis=1)

# %%
target=pd.concat([df.PE],axis=1)

# %%
x1=df["AT"]
x2=df["V"]
x3=df["AP"]
x4=df["RH"]
y=df["PE"]

# %% [markdown]
# ### Feature Scaling
#
# When we plot the graph for each feature with respect to target, the values are in different margin. To come under the same scale we need to normalize it. Here normalization can be done by calculating the difference of minimum and maximum value

# %%
x1=(x1-x1.min())/(x1.max()-x1.min())
x2=(x2-x2.min())/(x2.max()-x2.min())
x3=(x3-x3.min())/(x3.max()-x3.min())
x4=(x4-x4.min())/(x4.max()-x4.min())
y=(y-y.min())/(y.max()-y.min())

# %% [markdown]
# #### Plotting the graph for all features with respect to target

# %%
plt.plot(x1,y,'g.')
plt.xlabel("Temperature")
plt.ylabel("Electric Energy")
# Out:
# Text(0, 0.5, 'Electric Energy')

# %%
plt.plot(x2,y,'g.')
plt.xlabel("Vaccum")
plt.ylabel("Electric Energy")
# Out:
# Text(0, 0.5, 'Electric Energy')

# %%
plt.plot(x3,y,'g.')
plt.xlabel("Pressure")
plt.ylabel("Electric Energy")
# Out:
# Text(0, 0.5, 'Electric Energy')

# %%
plt.plot(x4,y,'g.')
plt.xlabel("Humidity")
plt.ylabel("Electric Energy")
# Out:
# Text(0, 0.5, 'Electric Energy')

# %% [markdown]
# Performing the pearson's correlation for choosing the best feature which is highly related to the target values[PE]

# %%
corelation=df.corr('pearson')

# %%
corelation
# Out:
#           AT         V        AP        RH        PE
# AT  1.000000  0.844107 -0.507549 -0.542535 -0.948128
# V   0.844107  1.000000 -0.413502 -0.312187 -0.869780
# AP -0.507549 -0.413502  1.000000  0.099574  0.518429
# RH -0.542535 -0.312187  0.099574  1.000000  0.389794
# PE -0.948128 -0.869780  0.518429  0.389794  1.000000

# %%
corelation["PE"].sort_values()
# Out:
# AT   -0.948128
# V    -0.869780
# RH    0.389794
# AP    0.518429
# PE    1.000000
# Name: PE, dtype: float64

# %%
X1=np.array(x1)
X2=np.array(x2)
X3=np.array(x3)
X4=np.array(x4)
Y=np.array(y)

# %% [markdown]
# ### Splitting the dataset
#
# We are splitting the dataset for training and testing the datapoints in the ratio 3:2.So that we can train our model and test the datapoints on the same model.

# %%
X1_train,X1_test,X2_train,X2_test,X3_train,X3_test,X4_train,X4_test,Y_train,Y_test=train_test_split(X1,X2,X3,X4,Y,test_size=0.2)

# %% [markdown]
# ## Linear Regression
# ### Hypothesis Equation
#
# As above mentioned we need to predict the electric energy output so that by analysing the data visualization we can choose straight line equation to fit the model covering all the points with less error.
#
# Here we are using all features(x1,x2,x3,x4) of the dataset.a,b,c,d,f represents the weights.

# %%
def hypothesis(a,b,c,d,f,x1,x2,x3,x4):
    return a*x1+b*x2+c*x3+d*x4+f

# %% [markdown]
# ### Error Equation
#
# When we plot the hypothesis equation to represent the model, all data points are not covered.There is some error with actual datapoint and the hypothesis equation representation.So we need to calculate the error for all the datapoints in the model with respect to the hypothesis equation values.
#
# Error is find out by taking difference between the hypothesis equation and actual data point(y).We are finding the mean(m) of all the errors for the particular hypothesis equation.
#
# Suppose if there is any negative error value the sum may be zero so that, we are finding the square of the difference between the hypothesis equation datapoint and actual data point.It leads to all positive error values.Since we are squaring the difference we need to reduce by 2.
#
# This function we called it as mean square error equation.

# %%
def error(a,b,c,d,f,x1,x2,x3,x4,y):
    e = 0
    m = len(x1)
    for i in range(m):
        e += np.power((hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i])-y[i]), 2)
    
    return (1/(2*m))*e

# %% [markdown]
# ### Step Gradient Equation
#
# When we plot the error equation with respect to the weights we will get the curve something like parabola. Our aim to minimize the error such that it should reach the global minima of the parabola curve.We dont know where is our data point in the parabola curve so that to reach the global minima we need to differenciate the error equation with respect to the weight to get the slope of that particular data point.
#
# Gradient descent equation represented by grad_a,grad_b,grad_c,grad_d,grad_f
#
# If the slope of the data point is negative then we need to move towards right to reach the global minima so that we should add small value to weights. Simillarly if the slope of the data point is positive then we need to move towards left to reach the global minima so that we should subtract small value to weights.
#
# We need to update the particular weight after adding or subtracting the small values represented by a,b,c,d,f
#
# Learning rate defines the step size to read the global minima.Suppose if the step size is large then it may cross the global minima leads to the overfit the model.To avoid these kind of issues we are defining the learning rate.It tells the how much steps should be moved.

# %%
def step_gradient(a,b,c,d,f,x1,x2,x3,x4,y,learning_rate):
    grad_a = 0
    grad_b = 0
    grad_c = 0
    grad_d = 0
    grad_f = 0
    m = len(x1)
    for i in range(m):
        grad_a += 2/m * (hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i]) - y[i]) * x1[i]
        grad_b += 2/m * (hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i]) - y[i]) * x2[i]
        grad_c += 2/m * (hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i]) - y[i]) * x3[i]
        grad_d += 2/m * (hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i]) - y[i]) * x4[i]
        grad_f += 2/m * (hypothesis(a,b,c,d,f,x1[i],x2[i],x3[i],x4[i]) - y[i])
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    c = c - (grad_c * learning_rate)
    d = d - (grad_d * learning_rate)
    f = f - (grad_f * learning_rate)
    return a, b, c, d, f

# %% [markdown]
# ### Descend Function
#
# We are intialising the values of a,b,c,d,f. Iterations tells about how many times we are training the model.In this function we are printing the values of error at every 1000 iteration.

# %%
def descend(initial_a, initial_b, initial_c, intial_d, intial_f, x1, x2, x3, x4, y, learning_rate, iterations):
    a = initial_a
    b = initial_b
    c = initial_c
    d = intial_d
    f = intial_f
    for i in range(iterations):
        e = error(a, b, c, d, f, x1, x2, x3, x4, y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}, c: {c}, d:{d}, f:{f}")
        
        a, b, c,d,f = step_gradient(a, b, c, d, f, x1, x2, x3, x4, y, learning_rate)

    return a, b, c, d, f

# %% [markdown]
# We need to change the weights to generalized the model so that the we can predict the electric energy for the given features with less error

# %%
a = -0.9092694976113486
b = -0.18475057841959358
c = 0.03637016909227834
d =-0.15228915190115783
f =1.08544157390645
learning_rate = 0.05
iterations = 10000

# %%
final_a,final_b,final_c,final_d,final_f=descend(a,b,c,d,f,X1_train,X2_train,X3_train,X4_train,Y_train,learning_rate,iterations)
# Out:
# Error: 0.00176964654194982, a: -0.9092694976113486, b: -0.18475057841959358, c: 0.03637016909227834, d:-0.15228915190115783, f:1.08544157390645
# Error: 0.0017681985723373525, a: -0.9185192509463823, b: -0.17910350276103268, c: 0.03687759388601726, d:-0.15329461361380414, f:1.0875531198476347
# Error: 0.0017677192449959318, a: -0.9235215132689026, b: -0.17550868586068336, c: 0.035852758407832946, d:-0.15500398706833343, f:1.0898417857025828
# Error: 0.0017674998090768282, a: -0.9268089278060636, b: -0.1733914980476636, c: 0.03480224241211496, d:-0.15627285741733815, f:1.0917594032818927
# Error: 0.0017673948758939306, a: -0.9290321381818296, b: -0.17204698224818177, c: 0.03395522739097471, d:-0.15718118944603043, f:1.0932036299475822
# Error: 0.0017673441563993589, a: -0.9305580394241162, b: -0.17115450500634, c: 0.03332626279764988, d:-0.15782197158951705, f:1.0942461008864035
# Error: 0.0017673195785041177, a: -0.9316131262139932, b: -0.1705477943894962, c: 0.03287503652746834, d:-0.15827097958448844, f:1.0949844741949077
# Error: 0.0017673076612614344, a: -0.9323453353157257, b: -0.1701302856374672, c: 0.03255633886820247, d:-0.15858460196443636, f:1.0955028631052093
# Error: 0.001767301882052323, a: -0.9328543813813304, b: -0.16984122415458294, c: 0.032332890677656205, d:-0.1588033230355101, f:1.0958652818548043
# Error: 0.001767299079359421, a: -0.9332085878183269, b: -0.1696404938983273, c: 0.03217677277303471, d:-0.1589557460727982, f:1.0961181466127314

# %%
error(final_a,final_b,final_c,final_d,final_f,X1_train,X2_train,X3_train,X4_train,Y_train)
# Out:
# 0.049300773760160434

# %%
error(final_a,final_b,final_c,final_d,final_f,X1_test,X2_test,X3_test,X4_test,Y_test)
# Out:
# 0.048142247667060545

# %% [markdown]
# #### Root mean squared error for trained data

# %%
np.sqrt(error(final_a,final_b,final_c,final_d,final_f,X1_train,X2_train,X3_train,X4_train,Y_train))
# Out:
# 0.22203777552515797

# %% [markdown]
# #### Root mean squared error for test data

# %%
np.sqrt(error(final_a,final_b,final_c,final_d,final_f,X1_test,X2_test,X3_test,X4_test,Y_test))
# Out:
# 0.21941341724484523

# %% [markdown]
# ## Linear Regression using Sklearn

# %%
X=np.array(feature)
Y=np.array(y)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(feature,Y,test_size=0.2)

# %% [markdown]
# Importing Linear Regression sklearn model

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %% [markdown]
# Fitting the Linear Model for trained dataset

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Predicting the Linear Model for test datapoints

# %%
Y_pred=regressor.predict(X_test)

# %%
for i in zip(Y_pred,Y_test):
    print(i)
# Out:
# (0.8089735650403698, 0.8507284768211923)
# (0.6838798430352542, 0.6992052980132453)
# (0.38306401501317255, 0.4630463576158945)
# (0.7650124893472912, 0.7784105960264899)
# (0.22100337771039613, 0.25721854304635783)
# (0.8092480185939772, 0.8613245033112586)
# (0.6307818376171602, 0.6245033112582786)
# (0.22952820531953566, 0.2617218543046356)
# (0.7577442403768632, 0.7811920529801327)
# (0.6984506196968447, 0.7490066225165565)
# (0.3344559966506021, 0.224503311258278)
# (0.259671742135872, 0.2144370860927152)
# (0.764577465200337, 0.7386754966887414)
# (0.7526589936261892, 0.7962913907284769)
# (0.30203056004857043, 0.30476821192052966)
# (0.6501955716323503, 0.6912582781456953)
# (0.8008406869680557, 0.8578807947019865)
# (0.2725896337041336, 0.3600000000000001)
# (0.6063653310338882, 0.6070198675496686)
# (0.38469558075922794, 0.3090066225165561)
# (0.13171664488950297, 0.16119205298013267)
# (0.48769134371951167, 0.4847682119205301)
# (0.24297683778808998, 0.2888741721854305)
# (0.4529144585641195, 0.43576158940397397)
# (0.6564358205443165, 0.545430463576159)
# (0.04925491535888171, 0.1305960264900664)
# (0.19750699781623982, 0.2211920529801323)
# (0.7585832791400698, 0.7127152317880795)
# (0.19477539605345584, 0.1211920529801329)
# (0.5027977336105142, 0.4621192052980131)
# (0.28067801844790063, 0.16490066225165548)
# (0.3842602696269396, 0.2788079470198677)
# (0.5314812916937071, 0.22357615894039728)
# (0.42358041182884343, 0.5201324503311255)
# (0.8291418361718323, 0.8320529801324502)
# (0.18363836213909174, 0.25430463576158924)
# (0.28792205784606884, 0.35629139072847726)
# (0.7688777986253886, 0.8397350993377488)
# (0.4148508055375066, 0.3719205298013243)
# (0.35905735700179026, 0.45589403973509957)
# (0.4672239674618367, 0.36516556291390717)
# (0.45628909227177805, 0.4339072847682118)
# (0.5906965333739769, 0.6067549668874173)
# (0.6982599555924337, 0.7443708609271522)
# (0.27220860710128464, 0.2721854304635763)
# (0.5054414444846123, 0.4849006622516558)
# (0.6446397689464496, 0.6219867549668879)
# (0.36602469065270543, 0.38092715231788066)
# (0.2473365243067127, 0.26543046357615924)
# (0.6971302103349546, 0.783841059602649)
# (0.193315359354078, 0.22437086092715228)
# (0.17532778668393784, 0.2109933774834438)
# (0.6359356448600393, 0.5621192052980132)
# (0.5779593579879203, 0.5090066225165564)
# (0.4595606337132069, 0.3904635761589406)
# (0.6171922466433601, 0.6569536423841063)
# (0.23957716099962406, 0.2780132450331127)
# (0.8263926392342997, 0.8756291390728479)
# (0.3380025991203826, 0.2847682119205298)
# (0.7317401624509974, 0.7104635761589402)
# (0.11680883249486007, 0.2764238410596027)
# (0.3003774872846027, 0.2662251655629142)
# (0.5590247872261943, 0.5749668874172189)
# (0.22574470741473202, 0.2107284768211924)
# (0.5886821828847454, 0.5101986754966885)
# (0.6648930629604857, 0.7299337748344372)
# (0.7233336458589817, 0.7066225165562917)
# (0.15170064389662175, 0.19880794701986743)
# (0.640268145453669, 0.7347019867549672)
# (0.6993292616585458, 0.5907284768211923)
# (0.5019496567343185, 0.4798675496688744)
# (0.5298650098524107, 0.5180132450331127)
# (0.14548881067577885, 0.10410596026490085)
# (0.12612720255380971, 0.16927152317880834)
# (0.8213323292117586, 0.3108609271523182)
# (0.3716140291947471, 0.3324503311258281)
# (0.14624234128914232, 0.18079470198675543)
# (0.853400556154996, 0.9027814569536428)
# (0.3966335716733657, 0.3982781456953641)
# (0.1470338598596625, 0.22887417218543085)
# (0.9005640060884095, 0.9060927152317884)
# (0.14561702569524326, 0.11298013245033152)
# (0.659500644314396, 0.5765562913907288)
# (0.26512688895317865, 0.26754966887417203)
# (0.39058223551378146, 0.5217218543046356)
# (0.5386159069178837, 0.49364238410596)
# (0.3956894520456443, 0.4169536423841062)
# (0.44187340512955153, 0.39152317880794707)
# (0.4303822047174517, 0.4915231788079472)
# (0.34818747580834675, 0.3207947019867553)
# (0.0915385410536006, 0.1252980132450336)
# (0.3786018567865532, 0.377615894039735)
# (0.9712871926075393, 0.9282119205298011)
# (0.5632657773589437, 0.5144370860927157)
# (0.23958117729467715, 0.22847682119205298)
# (0.2935537341194225, 0.16450331125827836)
# (0.3262886350909597, 0.2879470198675498)
# (0.30908988361265594, 0.32145695364238386)
# (0.5221495206212536, 0.503973509933775)
# (0.4844021184480427, 0.514701986754967)
# (0.20330369863885078, 0.28662251655629123)
# (0.5646490724981613, 0.4924503311258279)
# (0.8108069491082179, 0.8005298013245032)
# (0.2908893336177721, 0.2588079470198678)
# (0.5841719865793025, 0.570596026490066)
# (0.363061827801479, 0.40304635761589414)
# (0.16975941372411618, 0.19788079470198672)
# (0.7079206883979793, 0.6471523178807949)
# (0.569264584680235, 0.5460927152317884)
# (0.831539557203343, 0.812582781456954)
# (0.3627057581611977, 0.40728476821192056)
# (0.6471578415013786, 0.6729801324503312)
# (0.8418370119922379, 0.8190728476821196)
# (0.32734485291378274, 0.27668874172185415)
# (0.2910166219924243, 0.22754966887417227)
# (0.0559804235269834, 0.2652980132450335)
# (0.22100337771039613, 0.25721854304635783)
# (0.18794774538582032, 0.25006622516556287)
# (0.7998695179831038, 0.9241059602649004)
# (0.8010513059022103, 0.7549668874172185)
# (0.4109948239479324, 0.3545695364238408)
# (0.30494989793088806, 0.22238410596026517)
# (0.4033976502588974, 0.43099337748344396)
# (0.8567261795097911, 0.934172185430464)
# (0.2541310066016927, 0.2076821192052981)
# (0.24518185466388248, 0.25801324503311285)
# (0.6624170108342005, 0.6320529801324507)
# (0.5807217940798862, 0.6230463576158943)
# (0.7940716245800098, 0.7311258278145694)
# (0.31679612318431855, 0.2970860927152319)
# (0.6536348373330879, 0.5850331125827817)
# (0.3402749061853946, 0.36172185430463577)
# (0.7808425633912931, 0.7343046357615893)
# (0.43571834310309643, 0.47178807947019874)
# (0.6181970762941755, 0.5384105960264906)
# (0.7270970141586932, 0.8056953642384104)
# (0.8004514858718266, 0.8280794701986752)
# (0.2698623319093751, 0.33218543046357596)
# (0.1757211650758802, 0.09880794701986803)
# (0.43294514895742, 0.6556291390728477)
# (0.10903501498520018, 0.1900662251655632)
# (0.614026662800066, 0.6189403973509936)
# (0.7658833330655311, 0.8382781456953645)
# (0.1873326341209251, 0.15774834437086127)
# (0.1855627932574428, 0.10119205298013227)
# (0.4012241277637687, 0.44437086092715244)
# (0.14423173592045213, 0.10596026490066225)
# (0.5058835403250782, 0.44715231788079457)
# (0.7067334114811629, 0.7103311258278145)
# (0.2373311330677046, 0.16291390728476837)
# (0.4148596760025436, 0.4713907284768216)
# (0.44075145592812104, 0.3659602649006622)
# (0.641056071393793, 0.6384105960264899)
# (0.5323284042727726, 0.5132450331125827)
# (0.7919879154026325, 0.8454304635761587)
# (0.339892313210593, 0.345298013245033)
# (0.5800591653271434, 0.5992052980132452)
# (0.35170758876079267, 0.31695364238410606)
# (0.8396190298942712, 0.912582781456954)
# (0.16708268667822368, 0.2178807947019866)
# (0.5774988695230167, 0.5222516556291391)
# (0.3123863633897004, 0.23867549668874147)
# (0.5188167876657747, 0.571390728476821)
# (0.5967824446047486, 0.593245033112583)
# (0.42418971047683984, 0.5052980132450335)
# (0.31505001902021346, 0.24900662251655645)
# (0.7750489803456625, 0.7411920529801329)
# (0.4212020202011099, 0.3884768211920528)
# (0.4532558749551238, 0.4956291390728479)
# (0.4022028129284194, 0.3549668874172187)
# (0.6329885159652453, 0.647549668874172)
# (0.2084633107008404, 0.1782781456953647)
# (0.8421753739002644, 0.8631788079470201)
# (0.06862072777725181, 0.16251655629139047)
# (0.4483771281971981, 0.4377483443708611)
# (0.36944167953639623, 0.265165562913907)
# (0.19312998909710977, 0.2027814569536424)
# (0.16064270684198195, 0.23682119205298008)
# (0.3269710487154959, 0.40092715231788056)
# (0.6840439927553643, 0.6694039735099341)
# (0.12099955645298777, 0.30874172185430465)
# (0.5607156609934958, 0.5601324503311261)
# (0.34909511990230147, 0.39311258278145705)
# (0.3511677265346164, 0.46092715231788095)
# (0.326403771776755, 0.23364238410596008)
# (0.38648832396902066, 0.3633112582781458)
# (0.1933742386837542, 0.24172185430463577)
# (0.6442909776645648, 0.7509933774834435)
# (0.6410754853755558, 0.6750993377483447)
# (0.3272371357286267, 0.27668874172185415)
# (0.6793076484489577, 0.7715231788079471)
# (0.4238150324026081, 0.4100662251655634)
# (0.4369591377609451, 0.38437086092715206)
# (0.00830572695399412, 0.15682119205298056)
# (0.17495459858639412, 0.17284768211920545)
# (0.4351662172024173, 0.41973509933774833)
# (0.5936527870550514, 0.5956291390728481)
# (0.8436497132562883, 0.8336423841059603)
# (0.8285014808671105, 0.7855629139072848)
# (0.18378723955782583, 0.3316556291390731)
# (0.12369328437575744, 0.200927152317881)
# (0.1809746537436004, 0.24715231788079503)
# (0.031002306008875213, 0.13112582781457)
# (0.6435335680442447, 0.6172185430463579)
# (0.3226648134645658, 0.19549668874172174)
# (0.7694836790291846, 0.7385430463576158)
# (0.6953448439962809, 0.7545695364238414)
# (0.7919431743087841, 0.8754966887417222)
# (0.520973259799528, 0.4339072847682118)
# (0.8217376581982373, 0.9267549668874175)
# (0.40987387841750145, 0.38370860927152356)
# (0.28030862913286186, 0.3239735099337753)
# (0.7011827581287204, 0.7234437086092715)
# (0.187703289887928, 0.11576158940397363)
# (0.8064980638436152, 0.7721854304635763)
# (0.8835697957912405, 0.9101986754966891)
# (0.10743075954673498, 0.17192052980132475)
# (0.16359125908822586, 0.10198675496688726)
# (0.19479057303284408, 0.28609271523178836)
# (0.7185519252414986, 0.7294039735099337)
# (0.1310751275115417, 0.07483443708609316)
# (0.33161641343953263, 0.3694039735099336)
# (0.8943364427269526, 0.897880794701987)
# (0.2098840746181032, 0.29099337748344406)
# (0.6710806107458877, 0.580927152317881)
# (0.1375278945236415, 0.1932450331125832)
# (0.7931657260999845, 0.8026490066225168)
# (0.6115269109169775, 0.5486092715231791)
# (0.3637810242451179, 0.2773509933774834)
# (0.09094363927112237, 0.09298013245033089)
# (0.6563586406942603, 0.5369536423841063)
# (0.29111662558651025, 0.39152317880794707)
# (0.4424279708849982, 0.4739072847682123)
# (0.32772036264419824, 0.32622516556291387)
# (0.4378799255766965, 0.4867549668874172)
# (0.4051069821771646, 0.4170860927152319)
# (0.304549392027187, 0.29986754966887397)
# (0.4534802047603034, 0.4279470198675497)
# (0.22876174984077124, 0.3357615894039738)
# (0.36320034423752895, 0.34940397350993374)
# (0.4844055463132635, 0.44516556291390746)
# (0.5044752556566386, 0.5635761589403975)
# (0.5207504544347372, 0.5101986754966885)
# (0.662251236074979, 0.7871523178807948)
# (0.518311778023172, 0.6388079470198678)
# (0.6199823281098338, 0.6500662251655627)
# (0.2948060186593498, 0.2827814569536427)
# (0.15439833098180256, 0.21403973509933807)
# (0.11944070968415266, 0.17059602649006617)
# (0.6601966980799407, 0.602913907284768)
# (0.3365572450390226, 0.3623841059602651)
# (0.39587632334168943, 0.31271523178807964)
# (0.16536182480093886, 0.18794701986754964)
# (0.25317367871814944, 0.21059602649006667)
# (0.7847587575072403, 0.8646357615894044)
# (0.2747078060233515, 0.23629139072847724)
# (0.5599033678833343, 0.5631788079470196)
# (0.32203363544383334, 0.3578807947019865)
# (0.2484911455558798, 0.25337748344370853)
# (0.3160862706243551, 0.2996026490066226)
# (0.4309021337760186, 0.4630463576158945)
# (0.34987734252785485, 0.2788079470198677)
# (0.38832239873745006, 0.3703311258278151)
# (0.2978378659336996, 0.2784105960264898)
# (0.29462125517320714, 0.28463576158940407)
# (0.5865110416523458, 0.6574834437086091)
# (0.1518915900920168, 0.23245033112582797)
# (0.20717475624579862, 0.25165562913907286)
# (0.1890094203471438, 0.14384105960264917)
# (0.4168045001584977, 0.4380132450331125)
# (0.29628038115515376, 0.30172185430463616)
# (0.3506862524699328, 0.3535099337748344)
# (0.43711235452233466, 0.419867549668874)
# (0.48310777189769194, 0.4641059602649009)
# (0.20210741999001686, 0.3280794701986753)
# (0.4338764789221569, 0.4312582781456954)
# (0.7532504156705724, 0.7067549668874173)
# (0.371917313040279, 0.38860927152317926)
# (0.13197794761076131, 0.1398675496688742)
# (0.3148809685184579, 0.2622516556291392)
# (0.11371038670001465, 0.19364238410596032)
# (0.3989241004264217, 0.298278145695364)
# (0.13091226976821602, 0.12423841059602643)
# (0.6418427826003062, 0.6625165562913905)
# (0.17632684592736741, 0.10701986754966866)
# (0.40393126917303623, 0.41827814569536403)
# (0.7846728706439344, 0.7788079470198677)
# (0.5529908058117377, 0.5331125827814569)
# (0.5544178906081307, 0.5324503311258276)
# (0.40363131251876816, 0.37947019867549714)
# (0.29065500909922287, 0.25112582781457)
# (0.20764887666845305, 0.269139072847682)
# (0.5306416494336088, 0.419867549668874)
# (0.26144046347411376, 0.2652980132450335)
# (0.8424643227168348, 0.8374834437086095)
# (0.3258342099559326, 0.29536423841059617)
# (0.40597177516673133, 0.32357615894039743)
# (0.20779328198159736, 0.26503311258278134)
# (0.46122517029432714, 0.45059602649006597)
# (0.4360327336310997, 0.514701986754967)
# (0.5913576616664498, 0.5956291390728481)
# (0.7755818697865304, 0.8609271523178808)
# (0.353146936422934, 0.47364238410596016)
# (0.8105077016055495, 0.8080794701986754)
# (0.6937996163933132, 0.7656953642384107)
# (0.44354942220892424, 0.44900662251655676)
# (0.7686955805010486, 0.8569536423841058)
# (0.28974545414995473, 0.39152317880794707)
# (0.09663449082680087, 0.2026490066225167)
# (0.47503898942590045, 0.4630463576158945)
# (0.6548705311101881, 0.6909933774834439)
# (0.5140210623517512, 0.45072847682119244)
# (0.5387259981091828, 0.5847682119205303)
# (0.2985227338571524, 0.2863576158940398)
# (0.18615403700587307, 0.2921854304635762)
# (0.36297293502515043, 0.2847682119205298)
# (0.15514460183411355, 0.21298013245033093)
# (0.7416526757437625, 0.7185430463576159)
# (0.21550690259450295, 0.15350993377483485)
# (0.2212347223149569, 0.2676821192052985)
# (0.24457732709298996, 0.18728476821192036)
# (0.17537520119820493, 0.07774834437086099)
# (0.9201628289554679, 0.8601324503311258)
# (0.27164207244566935, 0.3364238410596031)
# (0.3615205067906674, 0.31377483443708604)
# (0.17467261824443792, 0.15509933774834486)
# (0.3893829878741507, 0.4373509933774832)
# (0.45996168960868733, 0.41377483443708624)
# (0.5059627714615931, 0.5712582781456953)
# (0.4489369404449876, 0.46331125827814595)
# (0.7013167126995932, 0.7410596026490065)
# (0.15511966290274715, 0.203311258278146)
# (0.7409359023746778, 0.8217218543046361)
# (0.6361738649258192, 0.5631788079470196)
# (0.18653493456762849, 0.17615894039735114)
# (0.31336252171654505, 0.324105960264901)
# (0.5110577621753765, 0.4964238410596029)
# (0.5893165717211909, 0.5813245033112581)
# (0.23202713352045445, 0.13271523178807923)
# (0.48519569241034244, 0.4990728476821193)
# (0.7194712841273958, 0.8384105960264903)
# (0.654434959727002, 0.6520529801324506)
# (0.42161655944007104, 0.36039735099337794)
# (0.6259889309657173, 0.646754966887417)
# (0.29098524098478684, 0.281854304635762)
# (0.7894585281565912, 0.8010596026490069)
# (0.15484033101744582, 0.20132450331125812)
# (0.3867931871692593, 0.3968211920529806)
# (0.33955971554766107, 0.3324503311258281)
# (0.4602478912728068, 0.4200000000000005)
# (0.6005678022147607, 0.6010596026490066)
# (0.5113226308627946, 0.45456953642384096)
# (0.2937456433122675, 0.17364238410596045)
# (0.4702390300495687, 0.5052980132450335)
# (0.5922951557591682, 0.6443708609271528)
# (0.51689196278953, 0.5104635761589407)
# (0.20711166350240728, 0.11231788079470223)
# (0.7927588819918494, 0.7939072847682119)
# (0.24743473737981958, 0.24158940397351006)
# (0.7837067179963089, 0.6079470198675502)
# (0.6134457387953904, 0.6807947019867554)
# (0.5795545447151066, 0.5214569536423842)
# (0.8077930404134829, 0.8501986754966887)
# (0.7180128242796625, 0.7398675496688744)
# (0.3047633091664413, 0.25496688741721857)
# (0.8288276863500812, 0.8945695364238413)
# (0.23427716613526423, 0.22490066225165586)
# (0.22473423961591954, 0.2845033112582784)
# (0.5545535413220963, 0.5827814569536424)
# (0.5828329497143904, 0.574569536423841)
# (0.1465771344971029, 0.06556291390728462)
# (0.55969613199471, 0.5927152317880795)
# (0.4228018096609735, 0.38927152317880775)
# (0.7276184100858729, 0.775496688741722)
# (0.3016036225669502, 0.2704635761589406)
# (0.14292374291790255, 0.1958940397350996)
# (0.08102469513212396, 0.13099337748344353)
# (0.8206124789842381, 0.8039735099337747)
# (0.6471062415379863, 0.6450331125827813)
# (0.44243934579774885, 0.3501986754966887)
# (0.6858426151992464, 0.6692715231788083)
# (0.7725087443005519, 0.9476821192052982)
# (0.22718590076052053, 0.20145695364238458)
# (0.13881801144948502, 0.14198675496688778)
# (0.33672337469710384, 0.2554966887417221)
# (0.5738153864627312, 0.5515231788079469)
# (0.3081386016473374, 0.24900662251655645)
# (0.5900259102026313, 0.6021192052980138)
# (0.2143056487136782, 0.22715231788079515)
# (0.8209536791277933, 0.8700662251655629)
# (0.26586197728278466, 0.31112582781456966)
# (0.28335127740172456, 0.37350993377483427)
# (0.8123705924825205, 0.8119205298013247)
# (0.6113308441968441, 0.5360264900662255)
# (0.6482073590226064, 0.6687417218543048)
# (0.21930945238987481, 0.1353642384105964)
# (0.3393294429617066, 0.3629139072847687)
# (0.6588948980639538, 0.5952317880794702)
# (0.531315946779219, 0.4602649006622517)
# (0.17997813995892586, 0.1362913907284771)
# (0.3781362024502431, 0.34543046357615875)
# (0.1895126988369107, 0.09483443708609304)
# (0.5963268931922019, 0.6720529801324504)
# (0.7505752098663919, 0.8607947019867551)
# (0.6052126966423499, 0.7471523178807951)
# (0.166819772616484, 0.1564238410596027)
# (0.7079961733952232, 0.8049006622516554)
# (0.6572980606174587, 0.6084768211920529)
# (0.3288668284482686, 0.3305960264900667)
# (0.6219117170031288, 0.44874172185430455)
# (0.27514722647172607, 0.25006622516556287)
# (0.3166100358069057, 0.2940397350993376)
# (0.6535374850666906, 0.723708609271523)
# (0.3169200875858157, 0.22701986754966869)
# (0.17872387366840842, 0.22582781456953657)
# (0.56304295363652, 0.5688741721854303)
# (0.32964358729598825, 0.3676821192052979)
# (0.4058256822173818, 0.46278145695364237)
# (0.4016770795348691, 0.4386754966887418)
# (0.3530607337953349, 0.3173509933774839)
# (0.19286709761088322, 0.21894039735099377)
# (0.12571931701832895, 0.275496688741722)
# (0.2682735748411763, 0.269139072847682)
# (0.7058839617001793, 0.670993377483444)
# (0.6740428533001727, 0.7638410596026493)
# (0.15905752293721692, 0.16662251655629118)
# (0.1893485954719345, 0.22410596026490087)
# (0.5907321247784384, 0.6074172185430465)
# (0.6341123537863448, 0.6418543046357621)
# (0.8558183828986935, 0.86635761589404)
# (0.1900199475371765, 0.12132450331125862)
# (0.6144862205298575, 0.6066225165562915)
# (0.6905984223374361, 0.5643708609271525)
# (0.5718195216645766, 0.648344370860927)
# (0.4953303709039517, 0.4082119205298012)
# (0.2690793581564078, 0.22397350993377516)
# (0.13683515563702808, 0.1907284768211925)
# (0.2818701573430621, 0.25006622516556287)
# (0.4338709194059044, 0.47668874172185444)
# (0.5606447802754948, 0.4782781456953644)
# (0.707985316606094, 0.7419867549668872)
# (0.14306849419701745, 0.1500662251655627)
# (0.4447928513809665, 0.4547019867549667)
# (0.373263123691835, 0.3664900662251658)
# (0.7693513631446071, 0.8350993377483446)
# (0.24731020667904124, 0.24993377483443716)
# (0.690614032450806, 0.7074172185430467)
# (0.6480498554522033, 0.5512582781456954)
# (0.18851328130566186, 0.2193377483443709)
# (0.17083704921965293, 0.20635761589403953)
# (0.818427531240552, 0.8639735099337751)
# (0.7008673587965706, 0.707284768211921)
# (0.5535631764221698, 0.5164238410596028)
# (0.7082765094459277, 0.7716556291390727)
# (0.291250850929562, 0.1874172185430468)
# (0.39721470574321527, 0.45165562913907314)
# (0.6101012824521409, 0.5811920529801324)
# (0.2572540220606182, 0.278675496688742)
# (0.30385473852448763, 0.21086092715231808)
# (0.5924489638903712, 0.5305960264900662)
# (0.4714111052369562, 0.4035761589403977)
# (0.6132605409793913, 0.5829139072847681)
# (0.7539260218373898, 0.8414569536423845)
# (0.749438826107356, 0.6511258278145698)
# (0.252799107668151, 0.2903311258278148)
# (0.6227121131899682, 0.6090066225165566)
# (0.7795231204543531, 0.8545695364238408)
# (0.25473353699579376, 0.18052980132450325)
# (0.7185323286048456, 0.6752317880794705)
# (0.36032062295263495, 0.38569536423841067)
# (0.5318611634090309, 0.2943046357615898)
# (0.37054088022834797, 0.3242384105960267)
# (0.20815174667034086, 0.2060927152317881)
# (0.32975620486131, 0.3389403973509938)
# (0.41999762547777086, 0.4046357615894041)
# (0.6521645545099916, 0.6637086092715233)
# (0.4920634890063187, 0.4170860927152319)
# (0.6325749137970623, 0.4415894039735104)
# (0.0886989174761299, 0.13682119205297993)
# (0.18585136385744433, 0.09589403973509945)
# (0.5525585405523693, 0.569801324503311)
# (0.5634948051188323, 0.5360264900662255)
# (0.2956596277875041, 0.29788079470198686)
# (0.2083323925255835, 0.2814569536423841)
# (0.3791873910885018, 0.2729801324503313)
# (0.29724784517095765, 0.23973509933774864)
# (0.6056273455582839, 0.5464900662251655)
# (0.30482455682273446, 0.2520529801324507)
# (0.4274060911022357, 0.379205298013245)
# (0.6763645019491938, 0.7238410596026494)
# (0.7839593461900166, 0.7871523178807948)
# (0.20746915818002104, 0.16635761589403977)
# (0.5145184686149957, 0.4996026490066229)
# (0.7399959264494516, 0.8385430463576159)
# (0.3252838755278319, 0.32688741721854314)
# (0.19066031459307264, 0.22754966887417227)
# (0.3674871070996607, 0.4038410596026491)
# (0.14851691148397034, 0.15721854304635768)
# (0.89919520150385, 0.8777483443708607)
# (0.22203361641489666, 0.2878145695364241)
# (0.7856380727655539, 0.7790728476821192)
# (0.25160789409330697, 0.24423841059602647)
# (0.08056454763616971, 0.1456953642384106)
# (0.2246568060840617, 0.1524503311258277)
# (0.6189661761723181, 0.5674172185430468)
# (0.6763264383900569, 0.7490066225165565)
# (0.3437106079942064, 0.2803973509933777)
# (0.40498283102865645, 0.3449006622516559)
# (0.7059009605596112, 0.8381456953642388)
# (0.19323068695352436, 0.25920529801324493)
# (0.23988700348321756, 0.17178807947019903)
# (0.7682780174425116, 0.7752317880794706)
# (0.7970363869471648, 0.8950993377483442)
# (0.7282421443700451, 0.7027814569536425)
# (0.25036479474600676, 0.2569536423841064)
# (0.6910751140293352, 0.730066225165563)
# (0.7673458804535255, 0.8254304635761589)
# (0.4992633281487686, 0.3772185430463579)
# (0.36539914364065906, 0.4066225165562912)
# (0.39371086777944664, 0.3741721854304636)
# (0.028416239385733566, 0.14860927152317918)
# (0.7624039042642878, 0.8452980132450331)
# (0.2231993943491375, 0.3438410596026495)
# (0.6032036678958144, 0.579337748344371)
# (0.7401295484717708, 0.7011920529801324)
# (0.1960840700702728, 0.10675496688741724)
# (0.562774599466815, 0.5341721854304634)
# (0.8699565181869138, 0.9823841059602652)
# (0.1624787293095265, 0.08662251655629166)
# (0.30572681493000214, 0.24503311258278146)
# (0.3263267878899924, 0.25059602649006646)
# (0.45084347532785174, 0.3890066225165564)
# (0.6271042329419682, 0.6437086092715235)
# (0.3340914163107969, 0.3079470198675497)
# (0.33731295046851945, 0.22900662251655657)
# (0.7836884450410866, 0.7923178807947019)
# (0.8306924305273882, 0.8227814569536425)
# (0.5435807680178657, 0.5364238410596026)
# (0.17574665046782195, 0.15549668874172198)
# (0.35399705403195153, 0.17589403973509973)
# (0.2689376850274319, 0.39364238410596064)
# (0.8717359300109783, 0.8796026490066229)
# (0.5330134466645717, 0.4925827814569536)
# (0.563589515462376, 0.5238410596026492)
# (0.6161607103367853, 0.6313907284768214)
# (0.16153127735025036, 0.1480794701986756)
# (0.7358138294215107, 0.6998675496688745)
# (0.6276880056807268, 0.6647682119205298)
# (0.556017979721704, 0.5807947019867553)
# (0.594086158315021, 0.5645033112582782)
# (0.6331923581564554, 0.6185430463576157)
# (0.7507138090146014, 0.8357615894039738)
# (0.4521766919377766, 0.40291390728476845)
# (0.41837883810955556, 0.42913907284768255)
# (0.3710140832296531, 0.299072847682119)
# (0.1850433629709668, 0.24251655629139077)
# (0.41805090517551546, 0.4052980132450334)
# (0.3350052362017502, 0.37311258278145715)
# (0.7323692893608411, 0.8075496688741726)
# (0.7673803009414658, 0.7549668874172185)
# (0.12871317651196224, 0.08013245033112598)
# (0.23659684276074833, 0.3398675496688745)
# (0.40282798751001, 0.419867549668874)
# (0.3112490833542473, 0.24807947019867574)
# (0.7667967200519087, 0.7603973509933778)
# (0.5639941669980834, 0.6123178807947022)
# (0.3039419385953916, 0.281854304635762)
# (0.3470388307883114, 0.4282119205298011)
# (0.5926469204285447, 0.5944370860927152)
# (0.4536045026504911, 0.451390728476821)
# (0.47450222458022484, 0.49536423841059646)
# (0.6973454516754474, 0.6023841059602651)
# (0.22876525547374832, 0.19311258278145674)
# (0.46097447090603366, 0.46940397350993374)
# (0.6290454347147945, 0.6246357615894043)
# (0.6203630050654614, 0.655496688741722)
# (0.535787610826794, 0.574569536423841)
# (0.3832764638181297, 0.30516556291390756)
# (0.6600312850836829, 0.6919205298013246)
# (0.44551796991822074, 0.44026490066225177)
# (0.27726778672032515, 0.22092715231788088)
# (0.1468804162308769, 0.2101986754966888)
# (0.3540728547075207, 0.3010596026490069)
# (0.20708322802806645, 0.17205298013245046)
# (0.43085767619423, 0.44675496688741745)
# (0.525566606180669, 0.526754966887417)
# (0.828667606692499, 0.7837086092715234)
# (0.3223082410768273, 0.277086092715232)
# (0.6456385770361932, 0.7132450331125831)
# (0.2231396348667975, 0.22728476821192087)
# (0.345078987142665, 0.3610596026490065)
# (0.6284111026381091, 0.5957615894039737)
# (0.14014316940783866, 0.14105960264900708)
# (0.7926472543879064, 0.7837086092715234)
# (0.6214786457915095, 0.5695364238410596)
# (0.34513898042208047, 0.3414569536423845)
# (0.25039932150659505, 0.18701986754966893)
# (0.5043570065730397, 0.42913907284768255)
# (0.1437004574321728, 0.22556291390728517)
# (0.4437870737461891, 0.43841059602649035)
# (0.5006286752719927, 0.37205298013245075)
# (0.13934145703344264, 0.08662251655629166)
# (0.45275499732644187, 0.41721854304635764)
# (0.09459296351926405, 0.1337748344370864)
# (0.3877943940440276, 0.4688741721854309)
# (0.4112936050871383, 0.3329801324503309)
# (0.4271294220488434, 0.427019867549669)
# (0.2378034812384422, 0.21139072847682167)
# (0.268071621604131, 0.2117880794701988)
# (0.2061230633852718, 0.23615894039735078)
# (0.422162579086805, 0.4071523178807948)
# (0.2196258651979054, 0.2837086092715234)
# (0.5526896313358055, 0.6021192052980138)
# (0.4067501954969283, 0.37258278145695356)
# (0.45626482087492004, 0.3748344370860929)
# (0.8919817094776681, 0.9794701986754966)
# (0.6037784492170122, 0.6727152317880798)
# (0.2818193563142291, 0.18317880794701966)
# (0.14865728348071056, 0.07483443708609316)
# (0.637130066307904, 0.6463576158940398)
# (0.19838463886825097, 0.20715231788079452)
# (0.7516715367278033, 0.8165562913907289)
# (0.2780149017969107, 0.23443708609271507)
# (0.46838164636334734, 0.4805298013245037)
# (0.3581886575976873, 0.3074172185430468)
# (0.30326989515255326, 0.20516556291390742)
# (0.08272533021353912, 0.09456953642384087)
# (0.4561980530416715, 0.46331125827814595)
# (0.38316056519225294, 0.3222516556291389)
# (0.6629471039967871, 0.7099337748344374)
# (0.284515759633036, 0.26503311258278134)
# (0.7153487985782482, 0.7735099337748349)
# (0.2869281402841526, 0.25655629139072855)
# (0.5621536505148557, 0.5875496688741724)
# (0.35318484096685926, 0.43986754966887465)
# (0.3353174007463541, 0.4247682119205297)
# (0.6548795447206428, 0.703311258278146)
# (0.6266397404656547, 0.6777483443708612)
# (0.6760663416144957, 0.7209271523178808)
# (0.1606889821833355, 0.18887417218543034)
# (0.4558382657202331, 0.4666225165562916)
# (0.7214927106181298, 0.7864900662251655)
# (0.46814102103264943, 0.11139072847682152)
# (0.22013029999468497, 0.22066225165562947)
# (0.701580460551231, 0.7190728476821194)
# (0.7083564750703512, 0.6704635761589405)
# (0.6731036704862606, 0.7246357615894045)
# (0.24864043413187353, 0.17284768211920545)
# (0.7450603902014945, 0.8211920529801324)
# (0.6338156162150134, 0.6479470198675499)
# (0.28651774078492376, 0.22582781456953657)
# (0.6773834272768471, 0.6782781456953647)
# (0.18415337927126046, 0.19284768211920533)
# (0.6991568456400709, 0.6064900662251659)
# (0.22816051557672518, 0.2896688741721855)
# (0.40938933755840323, 0.3357615894039738)
# (0.41355544885542606, 0.4011920529801327)
# (0.2483257126763735, 0.2871523178807948)
# (0.7607034661813552, 0.6978807947019867)
# (0.34965425013898477, 0.32132450331125817)
# (0.7460594121377289, 0.7362913907284773)
# (0.32592148379931263, 0.2813245033112584)
# (0.2307641161037597, 0.09947019867549657)
# (0.5967011391057742, 0.6364238410596028)
# (0.28327724376646574, 0.3890066225165564)
# (0.5564841101366218, 0.5937748344370859)
# (0.8345850563383987, 0.8829139072847686)
# (0.19388010419308677, 0.14609271523178846)
# (0.29662894205206836, 0.27178807947019845)
# (0.668925699139461, 0.7377483443708608)
# (0.599873372185927, 0.6283443708609271)
# (0.6515476146165672, 0.5888741721854309)
# (0.3057817331938083, 0.2907284768211919)
# (0.23187161464376638, 0.23417218543046367)
# (0.3553244853380323, 0.39364238410596064)
# (0.324688646348455, 0.3870198675496692)
# (0.17964943841544667, 0.2744370860927156)
# (0.2551881424226149, 0.2294039735099337)
# (0.2193934623465686, 0.19801324503311243)
# (0.4064912935979892, 0.4258278145695369)
# (0.09932503463362863, 0.20913907284768238)
# (0.10196621686209595, 0.09801324503311304)
# (0.10015504703640865, 0.09788079470198657)
# (0.6595635069639133, 0.6772185430463575)
# (0.3635466940897465, 0.3390728476821195)
# (0.3121725017758242, 0.24185430463576146)
# (0.19377113473362984, 0.16649006622516546)
# (0.19392052236368323, 0.14105960264900708)
# (0.6162987277099394, 0.4882119205298015)
# (0.17367249371444732, 0.17324503311258257)
# (0.3113811186730013, 0.2729801324503313)
# (0.4452820685300374, 0.46185430463576166)
# (0.24799150133775927, 0.24052980132450363)
# (0.4631299890066345, 0.46278145695364237)
# (0.779937493454573, 0.7574834437086092)
# (0.28303001449865167, 0.2821192052980134)
# (0.7348114530014598, 0.7096688741721853)
# (0.6139907327688943, 0.61682119205298)
# (0.81083392808764, 0.8345695364238409)
# (0.5914958631912276, 0.5600000000000004)
# (0.2056277116395957, 0.30476821192052966)
# (0.2757404428944316, 0.281059602649007)
# (0.8259859824562888, 0.8304635761589403)
# (0.40628970073400245, 0.30754966887417257)
# (0.5830685995042701, 0.5619867549668875)
# (0.36003981757963116, 0.3409271523178809)
# (0.23669544767509254, 0.28119205298013267)
# (0.23862478902374618, 0.19708609271523173)
# (0.14612951989213974, 0.18874172185430463)
# (0.48205605127462203, 0.5426490066225169)
# (0.3818199818661956, 0.38569536423841067)
# (0.24671564519707784, 0.2150993377483445)
# (0.8336124569547994, 0.8688741721854307)
# (0.38023843184092426, 0.4321854304635761)
# (0.6714444858160473, 0.614834437086093)
# (0.3398701075412891, 0.3237086092715232)
# (0.3437209407600892, 0.31549668874172176)
# (0.29264359326243733, 0.4316556291390733)
# (0.6630577062412509, 0.5725827814569538)
# (0.382698594533852, 0.3796026490066228)
# (0.3398584043789512, 0.3821192052980135)
# (0.21849451155944616, 0.2133774834437088)
# (0.15768891130159762, 0.1458278145695363)
# (0.5758508502486244, 0.6309933774834435)
# (0.31712557051189694, 0.23298013245033156)
# (0.03632881137424193, 0.18688741721854324)
# (0.6143657164420685, 0.6161589403973508)
# (0.18812719429703068, 0.28516556291390766)
# (0.7877856818861806, 0.8287417218543045)
# (0.2798835526454359, 0.2972185430463576)
# (0.7216621903195225, 0.822516556291391)
# (0.6662077867479146, 0.6184105960264901)
# (0.4715317341822929, 0.5003973509933779)
# (0.23602384967665713, 0.23695364238410577)
# (0.6304768748310294, 0.6023841059602651)
# (0.71055366128849, 0.7752317880794706)
# (0.6361572355004701, 0.5750993377483445)
# (0.7492537637381548, 0.7030463576158938)
# (0.4950134106699985, 0.4905960264900665)
# (0.6930367031692561, 0.7217218543046359)
# (0.33991113746683344, 0.23496688741721866)
# (0.32206876070428936, 0.23880794701986793)
# (0.7143718739964325, 0.7890066225165562)
# (0.4981113742067391, 0.4362913907284768)
# (0.2550697490954268, 0.17470198675496687)
# (0.6533169968610363, 0.6059602649006622)
# (0.47331930279022083, 0.43655629139072893)
# (0.244962423761157, 0.20966887417218522)
# (0.5734913917556625, 0.5280794701986755)
# (0.8293173598468082, 0.7321854304635765)
# (0.22335228800981372, 0.25496688741721857)
# (0.7771500651585475, 0.770728476821192)
# (0.2324824385192258, 0.17006622516556333)
# (0.14617092084250288, 0.11152317880794724)
# (0.23789872074566953, 0.2678145695364242)
# (0.44541276912471794, 0.427019867549669)
# (0.2931221818642851, 0.22675496688741728)
# (0.8517195900735315, 0.8886092715231793)
# (0.19302736095848294, 0.2186754966887416)
# (0.16480695409531143, 0.131920529801325)
# (0.604062652774975, 0.6320529801324507)
# (0.4437948838287146, 0.4867549668874172)
# (0.4798803498954176, 0.46927152317880805)
# (0.4106067428975565, 0.3741721854304636)
# (0.22492195525803405, 0.18304635761589394)
# (0.7426199658940267, 0.8380132450331124)
# (0.17064433264906637, 0.12635761589404002)
# (0.3698377318821634, 0.37350993377483427)
# (0.18494376959975756, 0.17218543046357615)
# (0.3244444566302928, 0.22927152317880797)
# (0.5400900717895953, 0.49364238410596)
# (0.519609305879088, 0.5120529801324507)
# (0.6380125726729479, 0.6227814569536422)
# (0.8947739364682338, 0.8821192052980136)
# (0.577522734736554, 0.5997350993377487)
# (0.8012547926675222, 0.8124503311258282)
# (0.41920318037758886, 0.44476821192052957)
# (0.45436639854197014, 0.38437086092715206)
# (0.07008280487448293, 0.17430463576158975)
# (0.592712906668329, 0.5870198675496688)
# (0.6251623060931532, 0.5271523178807949)
# (0.424146722001273, 0.4178807947019869)
# (0.2610894736523263, 0.31350993377483466)
# (0.34751884143403866, 0.35642384105960295)
# (0.44336068580193666, 0.4488741721854303)
# (0.11076950693519538, 0.16344370860927193)
# (0.6563718576400774, 0.540264900662252)
# (0.2002111030935751, 0.26092715231788066)
# (0.7970109366178527, 0.8279470198675496)
# (0.1600794320918042, 0.2741721854304634)
# (0.4220958460818347, 0.49046357615894076)
# (0.33778446535383294, 0.3948344370860927)
# (0.581658478921384, 0.5594701986754969)
# (0.15983150830372006, 0.14543046357615919)
# (0.12045891041923551, 0.11986754966887432)
# (0.4274056421667126, 0.35139072847682157)
# (0.4144180726918494, 0.3708609271523179)
# (0.5078142826728683, 0.6005298013245037)
# (0.7996335831758055, 0.8311258278145696)
# (0.48108860614488164, 0.4862251655629144)
# (0.5862037134671092, 0.6396026490066228)
# (0.9021871842210764, 0.9056953642384106)
# (0.24793666229082428, 0.2173509933774838)
# (0.32959571393864606, 0.277880794701987)
# (0.5551860927617667, 0.5743046357615896)
# (0.6649924794566867, 0.7075496688741724)
# (0.47920716315041034, 0.5006622516556293)
# (0.5585975674899655, 0.532317880794702)
# (0.8368726886118096, 0.8826490066225163)
# (0.3665119101062083, 0.3356291390728481)
# (0.31443461088576796, 0.2169536423841059)
# (0.6271756138771756, 0.4774834437086094)
# (0.5781876639205776, 0.5299337748344369)
# (0.35400668552255404, 0.34105960264900664)
# (0.27028511644686665, 0.2015894039735103)
# (0.6529486422669479, 0.5356291390728477)
# (0.6160721328791229, 0.6492715231788077)
# (0.12008817476885292, 0.06556291390728462)
# (0.432852678132454, 0.47456953642384087)
# (0.312915963557472, 0.23867549668874147)
# (0.7227917555269013, 0.7088741721854303)
# (0.14541682931441524, 0.18768211920529823)
# (0.47880972602243704, 0.4347019867549668)
# (0.23055738769947876, 0.27139072847682133)
# (0.2165230224854906, 0.18384105960264896)
# (0.7938835080966425, 0.8403973509933773)
# (0.3401345463608643, 0.4312582781456954)
# (0.5469240605966399, 0.5113907284768213)
# (0.7151107184636875, 0.7654304635761592)
# (0.21901556385154758, 0.25801324503311285)
# (0.1431088856203313, 0.0642384105960268)
# (0.3742026864596055, 0.4186754966887419)
# (0.0944171556627017, 0.1581456953642384)
# (0.5687921264430635, 0.582516556291391)
# (0.23550377473826067, 0.2637086092715235)
# (0.8072371583372394, 0.8344370860927153)
# (0.5397899355522751, 0.5027814569536428)
# (0.15615975755059303, 0.08317880794702026)
# (0.13059005757174325, 0.19205298013245034)
# (0.23570940761466957, 0.1466225165562913)
# (0.4266134675487994, 0.44529801324503315)
# (0.7862883451857918, 0.8827814569536429)
# (0.30347898598681156, 0.26264900662251633)
# (0.8788533264981645, 0.9152317880794705)
# (0.7832847880265396, 0.7713907284768213)
# (0.24379665773136588, 0.1891390728476825)
# (0.615185900327071, 0.5623841059602653)
# (0.6429716428892891, 0.6841059602649011)
# (0.2405400706793549, 0.18052980132450325)
# (0.43711083642567206, 0.38423841059602637)
# (0.5572637618184915, 0.529139072847682)
# (0.27626953117783415, 0.22701986754966869)
# (0.2044847832052082, 0.18158940397351042)
# (0.11231509684781582, 0.2119205298013245)
# (0.2024984443178604, 0.17205298013245046)
# (0.07879976210471185, 0.22211920529801302)
# (0.8102265757466287, 0.8716556291390729)
# (0.2898263414338675, 0.25456953642384145)
# (0.1001221427043203, 0.1354966887417221)
# (0.7693745928103375, 0.7251655629139073)
# (0.5864759081574471, 0.5690066225165568)
# (0.7331490465483996, 0.7521854304635764)
# (0.36738018325217586, 0.274701986754967)
# (0.3287172797354098, 0.32927152317880815)
# (0.6284254752621042, 0.6565562913907284)
# (0.4932748706264136, 0.5068874172185428)
# (0.41235654656793586, 0.3786754966887421)
# (0.5889692953430656, 0.610860927152318)
# (0.25032836452650337, 0.18807947019867535)
# (0.7168599806837419, 0.7313907284768215)
# (0.35461877345341297, 0.37311258278145715)
# (0.7882862930020484, 0.7883443708609269)
# (0.6506299582659207, 0.6704635761589405)
# (0.5576923538923543, 0.5754966887417217)
# (0.2494375876524172, 0.18291390728476825)
# (0.6957050167920104, 0.7609271523178807)
# (0.15543882147180205, 0.24225165562913933)
# (0.6710760940582303, 0.705695364238411)
# (0.35586074351918, 0.33854304635761595)
# (0.847943839204516, 0.8846357615894043)
# (0.37193547539365107, 0.37602649006622496)
# (0.3381321307507259, 0.3025165562913911)
# (0.4704094581389222, 0.4348344370860925)
# (0.864568479968272, 0.9152317880794705)
# (0.46578901934172345, 0.44821192052980174)
# (0.6040755151719613, 0.5990728476821194)
# (0.28443375705283835, 0.3104635761589404)
# (0.22190642309163694, 0.18092715231788112)
# (0.64864320001112, 0.655496688741722)
# (0.5435609265859311, 0.5256953642384106)
# (0.03289374714401716, 0.1345695364238414)
# (0.4063603878472129, 0.38874172185430494)
# (0.11769085887060382, 0.12304635761589432)
# (0.5520891928711679, 0.5601324503311261)
# (0.6201602285793294, 0.6458278145695363)
# (0.45637194685894855, 0.4337748344370861)
# (0.6959421799129278, 0.7052980132450332)
# (0.122165951492471, 0.19470198675496675)
# (0.19211254066660916, 0.09192052980132448)
# (0.07043435623480321, 0.13841059602648992)
# (0.20666235266991778, 0.1564238410596027)
# (0.4097819419560882, 0.4313907284768211)
# (0.30883007178257843, 0.2577483443708614)
# (0.3693887729046851, 0.4450331125827818)
# (0.09576430647230427, 0.1965562913907289)
# (0.4222586288014056, 0.40331125827814557)
# (0.5586633436123026, 0.4156291390728476)
# (0.5078739946756996, 0.5238410596026492)
# (0.2049293631751356, 0.1924503311258282)
# (0.7015778039204728, 0.7345695364238416)
# (0.6865322983716619, 0.689801324503311)
# (0.12098359315946128, 0.15139072847682128)
# (0.39380083972663293, 0.3618543046357615)
# (0.2878078746189544, 0.28953642384105976)
# (0.1732448755326612, 0.29841059602649045)
# (0.6098739771935552, 0.5455629139072847)
# (0.2988253096854039, 0.23960264900662293)
# (0.38516409351868774, 0.45509933774834455)
# (0.5808091253145846, 0.6936423841059604)
# (0.6501671040888582, 0.5901986754966888)
# (0.42734867925177733, 0.32635761589403955)
# (0.38159777409592766, 0.33178807947019884)
# (0.44662913405108107, 0.40900662251655623)
# (0.266237404612445, 0.28662251655629123)
# (0.705103779983094, 0.7904635761589405)
# (0.2162239244865679, 0.33417218543046384)
# (0.1039819796146777, 0.10039735099337728)
# (0.2745367010769771, 0.31907284768211963)
# (0.24689944831447924, 0.24993377483443716)
# (0.6435542533700492, 0.7038410596026489)
# (0.2337046000966217, 0.1925827814569539)
# (0.2321929327441693, 0.1411920529801328)
# (0.2656868659949411, 0.23258278145695369)
# (0.5582307587912568, 0.5633112582781461)
# (0.5583435102875985, 0.4312582781456954)
# (0.6493869878923527, 0.4827814569536422)
# (0.9028432116083109, 0.5245033112582784)
# (0.2825475148347166, 0.23006622516556297)
# (0.3288078633185973, 0.3630463576158944)
# (0.2656582653918189, 0.3019867549668876)
# (0.2521721737766159, 0.2904635761589405)
# (0.14009592922393976, 0.14993377483443698)
# (0.3458836945985367, 0.43006622516556325)
# (0.5559944113536653, 0.5597350993377482)
# (0.16454571005861307, 0.22900662251655657)
# (0.7180868488544575, 0.7398675496688744)
# (0.4451091693059702, 0.393907284768212)
# (0.09317086729826651, 0.11523178807947004)
# (0.3308121526755528, 0.34211920529801304)
# (0.6394164609379874, 0.6760264900662254)
# (0.6629160871957746, 0.6472847682119206)
# (0.3566330543624483, 0.3231788079470203)
# (0.2051106867770645, 0.22582781456953657)
# (0.6279962506017498, 0.6039735099337752)
# (0.3672906951042726, 0.39072847682119205)
# (0.2532382114483279, 0.17364238410596045)
# (0.6906481191538842, 0.7059602649006624)
# (0.6164139327683487, 0.5898013245033117)
# (0.34981095671833395, 0.4288741721854304)
# (0.7310159901733697, 0.7784105960264899)
# (0.6489307115482957, 0.6949668874172189)
# (0.4162428197985282, 0.45509933774834455)
# (0.5740494238424902, 0.5704635761589403)
# (0.13673504765844413, 0.19218543046357603)
# (0.3051451569090873, 0.3423841059602652)
# (0.5796382485188136, 0.5556291390728475)
# (0.3272457802360028, 0.30529801324503325)
# (0.5845070481058412, 0.5615894039735104)
# (0.5228968837103374, 0.4092715231788084)
# (0.3516223703070407, 0.39801324503311275)
# (0.2870638951189848, 0.36026490066225153)
# (0.8367386886455837, 0.8411920529801323)
# (0.33094936573662626, 0.33046357615894023)
# (0.587137089486999, 0.46847682119205303)
# (0.12046959333990837, 0.08834437086092736)
# (0.26183855402682293, 0.15774834437086127)
# (0.49884921634128476, 0.46198675496688735)
# (0.12521553472808455, 0.10609271523178795)
# (0.23582256050690464, 0.22503311258278158)
# (0.16854506144377712, 0.16423841059602695)
# (0.5340183208127459, 0.478807947019868)
# (0.5931447744086014, 0.5792052980132453)
# (0.35854678123180805, 0.4160264900662255)
# (0.40882277909571346, 0.49841059602649)
# (0.14341172819845976, 0.08649006622516596)
# (0.18657835822542929, 0.2652980132450335)
# (0.515004610966531, 0.44317880794702036)
# (0.719839497979635, 0.6727152317880798)
# (0.8211570499162157, 0.7896688741721855)
# (0.08449918023053815, 0.10887417218543083)
# (0.27103881200948343, 0.20026490066225172)
# (0.7336288781100744, 0.7100662251655631)
# (0.13245679635933216, 0.07258278145695388)
# (0.6252942706336095, 0.5925827814569538)
# (0.2556389530674791, 0.2145695364238409)
# (0.33923584674751084, 0.39059602649006636)
# (0.41467148812027366, 0.3679470198675501)
# (0.3878510903500125, 0.41483443708609263)
# (0.42100192359045596, 0.3904635761589406)
# (0.3113085505248204, 0.2251655629139073)
# (0.3589677115921828, 0.327284768211921)
# (0.8365892214674656, 0.8527152317880794)
# (0.5628874857358298, 0.4713907284768216)
# (0.2996043653448346, 0.25841059602648997)
# (0.5596670765073328, 0.5086092715231793)
# (0.5363404212272199, 0.5614569536423839)
# (0.2656723899203562, 0.12728476821192072)
# (0.2941296538423702, 0.3211920529801324)
# (0.17057512287946996, 0.21403973509933807)
# (0.19998280565469978, 0.22000000000000017)
# (0.6882119056754017, 0.6288741721854307)
# (0.15957026866551632, 0.08741721854304665)
# (0.6799223993544108, 0.7249006622516558)
# (0.3335369038386774, 0.2003973509933774)
# (0.2599164376067958, 0.18993377483443752)
# (0.6550888361125027, 0.6251655629139071)
# (0.5098392055302122, 0.4352317880794704)
# (0.374478391228522, 0.38781456953642424)
# (0.5345325297616819, 0.4176158940397355)
# (0.7907619915490463, 0.8026490066225168)
# (0.6812589219130228, 0.7210596026490066)
# (0.8862058478926753, 0.9411920529801325)
# (0.3319239058997631, 0.3011920529801326)
# (0.47507275756650674, 0.474834437086093)
# (0.455737446461006, 0.3817218543046357)
# (0.33124933308908444, 0.4245033112582783)
# (0.43468268961716583, 0.5582781456953647)
# (0.6876953846540793, 0.7177483443708609)
# (0.17175826371348407, 0.16304635761589406)
# (0.6182338201509621, 0.7177483443708609)
# (0.16640541779669593, 0.38927152317880775)
# (0.7819052981232807, 0.8748344370860929)
# (0.7540738111762335, 0.7533774834437086)
# (0.5093505844489776, 0.48794701986755007)
# (0.20044071227388832, 0.24860927152317858)
# (0.5426569060990967, 0.4523178807947024)
# (0.1638879152646079, 0.17125827814569544)
# (0.44541962620742903, 0.44185430463576175)
# (0.6182549604148173, 0.5958940397350995)
# (0.4469648685742609, 0.46940397350993374)
# (0.35473456173181056, 0.24675496688741716)
# (0.40501561360990157, 0.35973509933774866)
# (0.2667993383492165, 0.266754966887417)
# (0.19331634711276435, 0.18052980132450325)
# (0.6851944807285735, 0.6843708609271525)
# (0.2433284095652531, 0.2529801324503314)
# (0.2901358951532786, 0.23576158940397365)
# (0.12296439781645752, 0.1446357615894042)
# (0.46931433114976223, 0.4800000000000001)
# (0.7861583533027404, 0.8418543046357616)
# (0.7472174138457878, 0.8154966887417218)
# (0.5879032669978331, 0.617615894039735)
# (0.0652198831468519, 0.13324503311258282)
# (0.28829829353861375, 0.22317880794702016)
# (0.6945661049974488, 0.6500662251655627)
# (0.6084316072747317, 0.5944370860927152)
# (0.7431230228954127, 0.7288741721854308)
# (0.09822544751124751, 0.09668874172185446)
# (0.1453473493140771, 0.22092715231788088)
# (0.8429046858499802, 0.8972185430463577)
# (0.212590870028116, 0.10251655629139085)
# (0.5689595847349456, 0.5664900662251653)
# (0.6543975719364519, 0.5919205298013245)
# (0.6421755934172017, 0.5868874172185431)
# (0.33680129136094683, 0.30529801324503325)
# (0.6532439228081195, 0.6023841059602651)
# (0.42773330362778267, 0.4247682119205297)
# (0.4920508048210087, 0.4925827814569536)
# (0.5424531105526703, 0.6039735099337752)
# (0.2754332527612005, 0.21470198675496738)
# (0.378037486461558, 0.3643708609271522)
# (0.6510538602747981, 0.7299337748344372)
# (0.5400432611014935, 0.6164238410596029)
# (0.32161037666445824, 0.34940397350993374)
# (0.7903231476925784, 0.8721854304635764)
# (0.6122538639662614, 0.49139072847682147)
# (0.3828199606892994, 0.4296688741721854)
# (0.33845073053775426, 0.26490066225165565)
# (0.24167044129171822, 0.1782781456953647)
# (0.6959656669102693, 0.7536423841059607)
# (0.47883577484909623, 0.5)
# (0.28390959212421685, 0.28701986754966907)
# (0.6906141561360392, 0.7238410596026494)
# (0.32105011401474043, 0.29947019867549685)
# (0.6032026262383736, 0.5815894039735102)
# (0.2377780682629611, 0.18940397350993393)
# (0.21392485678502066, 0.26066225165562923)
# (0.18812306827669006, 0.15602649006622557)
# (0.3077734014278206, 0.3574834437086094)
# (0.6410052540496393, 0.612847682119205)
# (0.4151722174036184, 0.32185430463576176)
# (0.5691256045712908, 0.5642384105960268)
# (0.5437510946720938, 0.46397350993377523)
# (0.33633073492252435, 0.34357615894039734)
# (0.546651450352895, 0.5672847682119203)
# (0.8118050309489374, 0.8080794701986754)
# (0.6748471314106563, 0.554172185430464)
# (0.2893019834039807, 0.2643708609271528)
# (0.20368317277370934, 0.20384105960264884)
# (0.7818052677386989, 0.7305960264900666)
# (0.5580776777552487, 0.5596026490066225)
# (0.7744343716244823, 0.77112582781457)
# (0.09143975792219872, 0.1456953642384106)
# (0.06908290190245014, 0.1986754966887417)
# (0.35681444828664627, 0.25470198675496714)
# (0.3657335388678991, 0.27324503311258275)
# (0.35707312542446085, 0.2655629139072849)
# (0.6442550298756308, 0.5886092715231788)
# (0.3567483487205532, 0.300662251655629)
# (0.8374167245294928, 0.8206622516556297)
# (0.608464301648435, 0.5149668874172185)
# (0.1968069269365572, 0.298278145695364)
# (0.8805371602986728, 0.7806622516556291)
# (0.8230673620757921, 0.8166887417218547)
# (0.33613250024817953, 0.3079470198675497)
# (0.6890339111769033, 0.732847682119205)
# (0.3558645203291305, 0.3679470198675501)
# (0.7450165037424679, 0.735629139072848)
# (0.16891512603612713, 0.10860927152317866)
# (0.7135870172909513, 0.698543046357616)
# (0.6137956826398301, 0.6025165562913909)
# (0.4180183974464418, 0.3649006622516558)
# (0.6079286093354808, 0.6135099337748343)
# (0.288553333168638, 0.2569536423841064)
# (0.6819561969578576, 0.7156291390728481)
# (0.09996954399140778, 0.19231788079470175)
# (0.4414019851587341, 0.3679470198675501)
# (0.4503012036281878, 0.39748344370860916)
# (0.6158333028214628, 0.5841059602649009)
# (0.32954839947486186, 0.29192052980132477)
# (0.35119731341919713, 0.38026490066225216)
# (0.2375814555565648, 0.2577483443708614)
# (0.0207845319022657, 0.1405298013245035)
# (0.5545376432172703, 0.5841059602649009)
# (0.7671386362150914, 0.7923178807947019)
# (0.5620540869186283, 0.5611920529801325)
# (0.5589000982092376, 0.4882119205298015)
# (0.6984366043118598, 0.6966887417218546)
# (0.6033902783329999, 0.6527152317880799)
# (0.3440074557780321, 0.270728476821192)
# (0.4401697686181867, 0.4121854304635762)
# (0.36858544600819615, 0.31655629139072894)
# (0.3499943252589726, 0.3659602649006622)
# (0.5194784118048323, 0.49788079470198715)
# (0.6137037396671949, 0.576953642384106)
# (0.6909277144250541, 0.791788079470199)
# (0.3120182287983293, 0.2569536423841064)
# (0.24546076586506366, 0.24052980132450363)
# (0.717391232407585, 0.8112582781456954)
# (0.2023548189663989, 0.10384105960264943)
# (0.46413903245558175, 0.3850331125827814)
# (0.5626989277449808, 0.6438410596026491)
# (0.6860035549474078, 0.7613245033112586)
# (0.25614053459950176, 0.2242384105960266)
# (0.7787636353246216, 0.8135099337748346)
# (0.667737916869618, 0.6136423841059601)
# (0.4322070080500343, 0.4158940397350998)
# ...
# (0.6228306933053411, 0.5643708609271525)
# (0.6042772188812503, 0.5937748344370859)
# (0.31664288745407154, 0.3299337748344374)
# (0.5460569529737516, 0.5274172185430462)
# (0.29095423657346503, 0.2883443708609269)
# (0.1079386274202816, 0.16980132450331117)
# (0.3848299778269575, 0.46000000000000024)
# (0.7392724818256603, 0.8021192052980133)
# (0.11681577424029144, 0.19443708609271532)
# (0.26129745700839213, 0.2109933774834438)
# (0.1329952311854583, 0.2060927152317881)
# (0.25353475389872987, 0.2303311258278144)
# (0.5523642895428565, 0.5586754966887418)
# (0.5962569317469255, 0.6034437086092715)
# (0.2394506138385692, 0.20397350993377528)
# (0.7104794014348437, 0.7639735099337749)
# (0.6893361512398182, 0.7713907284768213)
# (0.30748029917510583, 0.32145695364238386)
# (0.23485276545251244, 0.22794701986755014)
# (0.15845423437896283, 0.12331125827814572)
# (0.15224984442759787, 0.1362913907284771)
# (0.5667620878183066, 0.596423841059603)
# (0.14763527269710142, 0.13523178807947067)
# (0.519530700577925, 0.5543046357615897)
# (0.70128523859889, 0.8566887417218544)
# (0.771582415578236, 0.814172185430464)
# (0.7682173134750507, 0.8598675496688744)
# (0.7921535575723442, 0.8055629139072846)
# (0.7226189356907865, 0.6707284768211919)
# (0.59332155151743, 0.5676821192052982)
# (0.6891792317640023, 0.6649006622516554)
# (0.8366217326805261, 0.8313907284768209)
# (0.7570706278250537, 0.798278145695364)
# (0.22626200841810284, 0.22066225165562947)
# (0.7970920604364714, 0.8124503311258282)
# (0.2675530624864863, 0.18516556291390754)
# (0.6938045086429928, 0.5222516556291391)
# (0.4695135165424822, 0.44079470198675536)
# (0.8629808294735255, 0.8192052980132454)
# (0.6225042866679847, 0.5989403973509937)
# (0.41181844018693115, 0.45311258278145744)
# (0.7270823254868355, 0.7242384105960266)
# (0.6604233361795714, 0.6347019867549671)
# (0.2711092771758084, 0.24251655629139077)
# (0.2653601685717815, 0.19629139072847673)
# (0.39100912145699385, 0.3331125827814574)
# (0.6144244325020436, 0.5740397350993381)
# (0.600879447028244, 0.48940397350993364)
# (0.3386875107460933, 0.2878145695364241)
# (0.3399235231981515, 0.3015894039735097)
# (0.3471261418383122, 0.3785430463576157)
# (0.11600945136734542, 0.1549668874172184)
# (0.5375044983981424, 0.5752317880794703)
# (0.40922160751069714, 0.3406622516556295)
# (0.29378174381224437, 0.24211920529801365)
# (0.6788230071445885, 0.738807947019868)
# (0.10926483273052123, 0.18357615894039753)
# (0.3002943231417802, 0.25417218543046355)
# (0.3001140820717065, 0.22701986754966869)
# (0.4679824460885783, 0.40794701986754983)
# (0.45853671207082547, 0.4388079470198675)
# (0.6854440477289272, 0.7860927152317884)
# (0.3622136990749185, 0.3384105960264902)
# (0.661091775066205, 0.6982781456953646)
# (0.2536451488932875, 0.2741721854304634)
# (0.1884578685274949, 0.1380132450331128)
# (0.6892651716717874, 0.6251655629139071)
# (0.8308321518008004, 0.8282119205298017)
# (0.24350008106176563, 0.20397350993377528)
# (0.8258976797299356, 0.8601324503311258)
# (0.2761644052814849, 0.2943046357615898)
# (0.21046051989051012, 0.23470198675496726)
# (0.4059297797195719, 0.4807947019867551)
# (0.3259442847534939, 0.30291390728476825)
# (0.6856187227838322, 0.6875496688741726)
# (0.35587531637590614, 0.27430463576158987)
# (0.09351558423150452, 0.16172185430463623)
# (0.25613696372562045, 0.24543046357615933)
# (0.13866278619464972, 0.08490066225165596)
# (0.6099381233840215, 0.610860927152318)
# (0.7389693105719586, 0.7863576158940397)
# (0.1976612923664713, 0.1866225165562918)
# (0.7052886792409849, 0.7063576158940396)
# (0.16293729192576906, 0.11735099337748363)
# (0.8110034063638147, 0.8509933774834437)
# (0.5927719504432288, 0.5760264900662253)
# (0.468280383968385, 0.5290066225165563)
# (0.32482538425733287, 0.35629139072847726)
# (0.6227494475071857, 0.6876821192052982)
# (0.5479336334938136, 0.586490066225166)
# (0.4492208141902807, 0.4336423841059604)
# (0.6388082966509315, 0.657880794701987)
# (0.7668929631555105, 0.75841059602649)
# (0.6157333688723604, 0.6843708609271525)
# (0.6620896657111681, 0.6908609271523182)
# (0.8091092017829511, 0.8585430463576158)
# (0.6293082555693283, 0.6370860927152321)
# (0.6790622969103199, 0.5807947019867553)
# (0.6127466304486598, 0.6393377483443706)
# (0.5378411069437692, 0.4900662251655629)
# (0.285153676183743, 0.24781456953642433)
# (0.5361734747517088, 0.5687417218543046)
# (0.3425029179228108, 0.30079470198675545)
# (0.1846491872446394, 0.16013245033112625)
# (0.3085447445505178, 0.23973509933774864)
# (0.3492639832990582, 0.3606622516556294)
# (0.12906608421334675, 0.1245033112582786)
# (0.5891551664659782, 0.6026490066225165)
# (0.1973831849797884, 0.25152317880794717)
# (0.24032934353716534, 0.2904635761589405)
# (0.28769210681345425, 0.25496688741721857)
# (0.5487786529590143, 0.5709933774834439)
# (0.1675511803799284, 0.11443708609271505)
# (0.6272073696404988, 0.5725827814569538)
# (0.40264713478053205, 0.40887417218543054)
# (0.6875682688473476, 0.7127152317880795)
# (0.278425163976314, 0.298278145695364)
# (0.7795391314531803, 0.8708609271523179)
# (0.606971645002113, 0.5210596026490071)
# (0.4768099992751841, 0.5182781456953641)
# (0.7278679070654119, 0.717218543046358)
# (0.2753483343524362, 0.31695364238410606)
# (0.21209501542800818, 0.11907284768211933)
# (0.3049072006797689, 0.26887417218543064)
# (0.28165273285429687, 0.2854304635761591)
# (0.5203292890441302, 0.45311258278145744)
# (0.5703881914716181, 0.5723178807947025)
# (0.5940510127214887, 0.6524503311258277)
# (0.5437913198098505, 0.614834437086093)
# (0.7895429901527453, 0.7088741721854303)
# (0.3503538630690696, 0.3001324503311262)
# (0.2962784669286594, 0.24927152317880785)
# (0.511737243816208, 0.585298013245033)
# (0.6869075740328622, 0.7225165562913909)
# (0.4312529990076507, 0.4177483443708612)
# (0.06796625300375503, 0.1417218543046356)
# (0.4993471571527253, 0.4866225165562915)
# (0.7231019946453359, 0.7843708609271527)
# (0.5022638202031072, 0.5553642384105961)
# (0.19794915129868312, 0.1981456953642389)
# (0.2680411493663332, 0.16609271523178834)
# (0.5063617607548109, 0.5264900662251656)
# (0.27903130908028706, 0.3242384105960267)
# (0.3457959371829551, 0.2896688741721855)
# (0.6548120003317832, 0.7409271523178808)
# (0.4328904062588604, 0.3405298013245038)
# (0.7197054012660163, 0.812185430463576)
# (0.3720606841946439, 0.30927152317880824)
# (0.6049209440672357, 0.6805298013245032)
# (0.35796032621846585, 0.2554966887417221)
# (0.4093545318593082, 0.3841059602649007)
# (0.24920260014490875, 0.18649006622516534)
# (0.291482024263586, 0.26344370860927135)
# (0.6760902908862948, 0.6399999999999999)
# (0.6194440825032784, 0.683841059602649)
# (0.3702065152929717, 0.39721854304635773)
# (0.28826208819476973, 0.25231788079470213)
# (0.17274301708168155, 0.2813245033112584)
# (0.6005943517846469, 0.5284768211920534)
# (0.4692755237714715, 0.40105960264900703)
# (0.2422733482384118, 0.2789403973509934)
# (0.33498284902788666, 0.3350993377483445)
# (0.33605781436173465, 0.3462251655629137)
# (0.14852727476150118, 0.14529801324503347)
# (0.10987209898669881, 0.17880794701986755)
# (0.26976695974466913, 0.30635761589403965)
# (0.3580476542491154, 0.31748344370860965)
# (0.3089476575711774, 0.2882119205298012)
# (0.38814350071667764, 0.29748344370860974)
# (0.23436184181712771, 0.20052980132450313)
# (0.18715637608991675, 0.23907284768211937)
# (0.7851785922256331, 0.7962913907284769)
# (0.44667946340916154, 0.4272847682119204)
# (0.8740359348249636, 0.8896688741721857)
# (0.7010335729957622, 0.770728476821192)
# (0.33506105005502684, 0.33019867549668885)
# (0.4133577603475815, 0.38860927152317926)
# (0.6032861047635547, 0.5925827814569538)
# (0.36285243815459145, 0.2627814569536428)
# (0.6201438355769754, 0.653112582781457)
# (0.8133733900488401, 0.9029139072847684)
# (0.2600358280261041, 0.2210596026490066)
# (0.18241368099746424, 0.18211920529801323)
# (0.8403210038972785, 0.8950993377483442)
# (0.6199583314276359, 0.5900662251655631)
# (0.21956805189470074, 0.17562913907284755)
# (0.17476274561995386, 0.16900662251655618)
# (0.6339581698024315, 0.6109933774834436)
# (0.39891670146157054, 0.4617218543046359)
# (0.17083251419862205, 0.2821192052980134)
# (0.33239580910257843, 0.35827814569536437)
# (0.3853343559428214, 0.31960264900662244)
# (0.597984323029287, 0.6692715231788083)
# (0.3134371223817403, 0.2947019867549669)
# (0.24853606767901837, 0.24052980132450363)
# (0.7439427018728209, 0.8283443708609274)
# (0.5534496770407084, 0.5866225165562916)
# (0.8019732461892038, 0.7960264900662255)
# (0.6335663384831771, 0.6423841059602649)
# (0.4089201858033538, 0.4185430463576162)
# (0.43524040992494567, 0.46675496688741736)
# (0.744458365653054, 0.8170860927152318)
# (0.4076390503928206, 0.36874172185430504)
# (0.4693464121357174, 0.5303311258278148)
# (0.052973850373533415, 0.17867549668874183)
# (0.22454552558939478, 0.17735099337748325)
# (0.16014843715680926, 0.1891390728476825)
# (0.6763219004838106, 0.6860927152317883)
# (0.5653349844554822, 0.5076821192052978)
# (0.10954033333099655, 0.17430463576158975)
# (0.3588071869890726, 0.3859602649006621)
# (0.19712159547410574, 0.17509933774834474)
# (0.4250714889285715, 0.4066225165562912)
# (0.3393397444401278, 0.26490066225165565)
# (0.1897687502896373, 0.20370860927152312)
# (0.27686017551020353, 0.31894039735099317)
# (0.2836842312520105, 0.3462251655629137)
# (0.7197243404181867, 0.7854304635761591)
# (0.3230772379927339, 0.2941721854304641)
# (0.1898036336254133, 0.20317880794702028)
# (0.801484316271575, 0.8827814569536429)
# (0.6749800581052597, 0.6429139072847685)
# (0.5642208779682922, 0.5553642384105961)
# (0.2628171055546954, 0.24172185430463577)
# (0.36173668160719774, 0.2868874172185434)
# (0.6295556447672527, 0.5854304635761588)
# (0.5228963267795603, 0.49046357615894076)
# (0.5031757825486475, 0.4173509933774833)
# (0.10997140620506485, 0.15443708609271556)
# (0.3187175968781611, 0.3643708609271522)
# (0.7799700865118595, 0.8625165562913908)
# (0.8014558615177532, 0.9231788079470197)
# (0.33433694203413983, 0.3320529801324502)
# (0.7149917762755238, 0.7165562913907287)
# (0.29032478253279786, 0.20198675496688742)
# (0.1714611701246564, 0.14384105960264917)
# (0.8650350158930328, 0.8382781456953645)
# (0.3416858366328613, 0.3723178807947022)
# (0.4594761544037645, 0.48450331125827795)
# (0.3427263236355896, 0.32013245033112603)
# (0.6390126223075875, 0.6486092715231792)
# (0.16790351481383142, 0.3353642384105959)
# (0.7439710860200193, 0.7569536423841065)
# (0.14092417152424652, 0.25337748344370853)
# (0.5177430559846121, 0.5309933774834441)
# (0.19858503418648382, 0.10609271523178795)
# (0.7442943449537698, 0.6797350993377482)
# (0.6183946063772879, 0.6658278145695362)
# (0.6096259317876422, 0.6845033112582782)
# (0.24913377222479866, 0.2638410596026492)
# (0.34333058079180123, 0.23443708609271507)
# (0.8028061178013451, 0.8509933774834437)
# (0.11488601391818554, 0.2210596026490066)
# (0.3140634287698963, 0.32198675496688745)
# (0.617698071145394, 0.6682119205298012)
# (0.2419741901457912, 0.2905960264900662)
# (0.4609644877774491, 0.48158940397351013)
# (0.44924500490354935, 0.44582781456953674)
# (0.0905421025775448, 0.2124503311258281)
# (0.7209650397836552, 0.7042384105960267)
# (0.5185878409630187, 0.44238410596026534)
# (0.8411541290887758, 0.8650331125827815)
# (0.5926089287188274, 0.6331125827814571)
# (0.5969970218557297, 0.5643708609271525)
# (0.6557612108448281, 0.6649006622516554)
# (0.48157902863196306, 0.4837086092715229)
# (0.2758511303178012, 0.2961589403973512)
# (0.18088577048846538, 0.13350993377483422)
# (0.7490943455554291, 0.8345695364238409)
# (0.12552036409292677, 0.1957615894039739)
# (0.7056716447970705, 0.714039735099338)
# (0.432065335641729, 0.39337748344370843)
# (0.5748961173235201, 0.5754966887417217)
# (0.42022469828060977, 0.3875496688741721)
# (0.15732773860957777, 0.2956291390728476)
# (0.5250821828253921, 0.3953642384105963)
# (0.29356370943287, 0.24450331125827862)
# (0.15243791910532978, 0.17708609271523185)
# (0.44248126372522323, 0.38344370860927135)
# (0.6337527660243689, 0.6478145695364241)
# (0.6223977479979165, 0.6699337748344368)
# (0.6199878848840331, 0.5231788079470199)
# (0.6371589995585771, 0.7002649006622517)
# (0.6333925691606366, 0.3406622516556295)
# (0.6424415014651517, 0.5581456953642382)
# (0.6440948443562139, 0.5842384105960267)
# (0.2862003494259682, 0.31112582781456966)
# (0.681347405229833, 0.5802649006622517)
# (0.19671934187055568, 0.16834437086092763)
# (0.5734132574483576, 0.5781456953642389)
# (0.6474456755762203, 0.5954966887417223)
# (0.36967280124442065, 0.3382781456953645)
# (0.6498778624380005, 0.6909933774834439)
# (0.314264468035315, 0.2793377483443713)
# (0.5936010263488027, 0.6438410596026491)
# (0.5920335755182724, 0.5570860927152318)
# (0.31369493210798743, 0.32384105960264886)
# (0.6129329686395014, 0.5778807947019867)
# (0.7090247969537198, 0.7687417218543049)
# (0.7711807931094596, 0.7215894039735101)
# (0.5653607049581969, 0.5586754966887418)
# (0.8221165248309305, 0.7974834437086098)
# (0.5967150346515759, 0.5782781456953646)
# (0.46060413014333745, 0.4705960264900666)
# (0.6386318539408565, 0.7262251655629137)
# (0.7572300247745658, 0.7675496688741721)
# (0.6682969407376441, 0.6127152317880793)
# (0.5314469028112953, 0.6234437086092715)
# (0.779059924280837, 0.8068874172185433)
# (0.5008649276358427, 0.45059602649006597)
# (0.47807086638500346, 0.49536423841059646)
# (0.7999994301406008, 0.9390728476821196)
# (0.15068279613668079, 0.23006622516556297)
# (0.3504471650748409, 0.39721854304635773)
# (0.6505264761358119, 0.5607947019867554)
# (0.12654411717960112, 0.22132450331125875)
# (0.420074199901207, 0.4389403973509932)
# (0.08103601774153868, 0.2303311258278144)
# (0.6244959419853124, 0.6249006622516557)
# (0.2440821709768325, 0.3157615894039739)
# (0.5991785355683904, 0.6211920529801329)
# (0.1261586041296806, 0.17390728476821185)
# (0.32199360646957376, 0.3491390728476823)
# (0.20655407374313484, 0.25814569536423854)
# (0.7762073244034193, 0.8488741721854309)
# (0.5449034661562693, 0.49443708609271503)
# (0.7951726894739803, 0.8360264900662252)
# (0.13221089846458622, 0.14596026490066202)
# (0.22121500829557234, 0.19099337748344392)
# (0.6064948213461401, 0.583311258278146)
# (0.6519989365450618, 0.4878145695364236)
# (0.7905886684218131, 0.6777483443708612)
# (0.2718853130079555, 0.20463576158940383)
# (0.32568555222027423, 0.281854304635762)
# (0.28797907124688665, 0.2635761589403978)
# (0.5672085282280773, 0.5282119205298013)
# (0.3302274890614935, 0.29986754966887397)
# (0.23929210774067067, 0.2573509933774835)
# (0.47481984688930734, 0.4185430463576162)
# (0.7533708929000343, 0.7504635761589408)
# (0.4756289108308423, 0.46794701986754944)
# (0.5494645496053078, 0.49841059602649)
# (0.5945444856907077, 0.5562913907284768)
# (0.21143073256916578, 0.19271523178807962)
# (0.8118913643297121, 0.9434437086092717)
# (0.48336114369372135, 0.44966887417218526)
# (0.6094696509366336, 0.5740397350993381)
# (0.1522173686561316, 0.15629139072847698)
# (0.1908006635484114, 0.3045033112582783)
# (0.63058293265666, 0.5846357615894038)
# (0.3872212138410134, 0.39814569536423844)
# (0.1349288451709773, 0.11165562913907294)
# (0.1375537883216031, 0.11430463576158935)
# (0.3253957679668538, 0.2941721854304641)
# (0.6785911080747655, 0.6965562913907289)
# (0.3281307406905898, 0.3157615894039739)
# (0.48099321157454206, 0.41973509933774833)
# (0.27240818234297065, 0.24463576158940434)
# (0.6640737284827742, 0.7305960264900666)
# (0.1903862087748619, 0.2027814569536424)
# (0.13812048308513925, 0.08688741721854308)
# (0.6894937340185335, 0.653112582781457)
# (0.8456848137411228, 0.889933774834437)
# (0.4823355635874972, 0.37390728476821217)
# (0.720978923506542, 0.811390728476821)
# (0.2978061543453845, 0.32741721854304673)
# (0.25475629697831476, 0.2121854304635759)
# (0.41498523918725283, 0.38384105960264925)
# (0.6080993066571049, 0.5578807947019868)
# (0.8264747093136666, 0.7989403973509933)
# (0.33395973587910116, 0.354039735099338)
# (0.8231512782393844, 0.7870198675496691)
# (0.23210092907390906, 0.16317880794701978)
# (0.22840163917133305, 0.2169536423841059)
# (0.20924967276065598, 0.1549668874172184)
# (0.2806864487012156, 0.2785430463576163)
# (0.7453725287002714, 0.6468874172185435)
# (0.65675791035231, 0.6675496688741727)
# (0.28305552963618097, 0.21324503311258308)
# (0.18069371015234198, 0.24463576158940434)
# (0.31165173531898016, 0.30026490066225187)
# (0.6377794022310259, 0.7037086092715231)
# (0.35208784701982265, 0.38993377483443703)
# (0.6440489249664186, 0.5886092715231788)
# (0.139051429118415, 0.2637086092715235)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Root mean squared error

# %%
np.sqrt(mean_squared_error(Y_test,Y_pred))
# Out:
# 0.06234696382394725

# %% [markdown]
# Computing the r2_score for Linear Regression

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.9225476624173136
